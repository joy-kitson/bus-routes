# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
orig = "/Users/HasanMahdi/Desktop/MATH512/Potential_Stops.csv"
better = "/Users/HasanMahdi/Desktop/MATH512/DemoByStopsSIMPLIFIED-1.xlsx"

# %%
original = pd.read_csv(orig, usecols = ['StopId','NumberWorkers'])
OtherSheet = pd.read_excel(better, sheet_name = 'Stop_DemosForArc', usecols = ['StopId','StopAbbr','Est_TotPop','Est_TotMinority','Est_TotPov','Est_TotLEP','Stop_PercMinority','Stop_PercPoverty', 'Stop_PercLEP','Est_Pop_Density_SqMile'])

# %%
original.head(10)
# Out:
#    StopId  NumberWorkers
# 0    3273          851.0
# 1    3972          185.0
# 2    2720          185.0
# 3    2740          851.0
# 4    3984          851.0
# 5    2998         1320.0
# 6    2743         2443.0
# 7    2745         1320.0
# 8    3560         1320.0
# 9    2746         1320.0

# %%
OtherSheet.head(10)
# Out:
#    StopId StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0    3273     GSKE         768              297         164          45
# 1    3972     WEAL         712              319         140          42
# 2    2720     WENA         693              300         135          39
# 3    2740     GOGU         367              165          30           9
# 4    3984     RVSC         321              156          17           5
# 5    2998     13SK         250               71          22           3
# 6    2743     CAMA         385              141          24           9
# 7    2745     NOCA         268               86          19           4
# 8    3560     NOVR         264               86          19           4
# 9    2746     NOWB         255               89          18           4
#
#    Stop_PercMinority  Stop_PercPoverty  Stop_PercLEP  Est_Pop_Density_SqMile
# 0              38.67             21.35          5.86                 3911.39
# ...

# %%
New = pd.merge(OtherSheet, original, on = 'StopId', how = 'inner')
New.head(100)
# Out:
#     StopId StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0     3273     GSKE         768              297         164          45
# 1     3972     WEAL         712              319         140          42
# 2     2720     WENA         693              300         135          39
# 3     2740     GOGU         367              165          30           9
# 4     3984     RVSC         321              156          17           5
# 5     2998     13SK         250               71          22           3
# 6     2743     CAMA         385              141          24           9
# 7     2745     NOCA         268               86          19           4
# 8     3560     NOVR         264               86          19           4
# 9     2746     NOWB         255               89          18           4
# 10    2747     CACW         269               86          19           4
# 11    2748     CACA         272               88          19           4
# ...

# %%
x = pd.read_excel("/Users/HasanMahdi/Desktop/MATH512/Stop_Riders_Ranking_by_Route_Daily_Totals_May_2019.xls", sheet_name = "Arc2019May",usecols = ['StopID','IndividUtilization',])

# %%
x.head()
# Out:
#    StopID  IndividUtilization
# 0       1            2.941645
# 1       1            1.829993
# 2       1            0.568039
# 3       1            0.172715
# 4       2            4.651952

# %%
x.drop_duplicates(inplace=True)
x_new = x.groupby(['StopID']).mean()

# %%
x_new.head(10)
# Out:
#         IndividUtilization
# StopID
# 1                 1.378098
# 2                 2.336949
# 3                 3.235269
# 4                 3.625616
# 6                 0.832390
# 7                 1.269269
# 8                 0.739273
# 9                 0.558452
# 10                1.280162
# 11                0.330745

# %%
New.rename(columns={'StopId' : 'StopID'}, inplace=True)

# %%
x_new.head()
# Out:
#         IndividUtilization
# StopID
# 1                 1.378098
# 2                 2.336949
# 3                 3.235269
# 4                 3.625616
# 6                 0.832390

# %%
good = pd.merge(New,x_new,on = "StopID",how = "inner")
good.head(20)
# Out:
#     StopID StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0     3273     GSKE         768              297         164          45
# 1     3972     WEAL         712              319         140          42
# 2     2720     WENA         693              300         135          39
# 3     2740     GOGU         367              165          30           9
# 4     3984     RVSC         321              156          17           5
# 5     2998     13SK         250               71          22           3
# 6     2743     CAMA         385              141          24           9
# 7     2745     NOCA         268               86          19           4
# 8     3560     NOVR         264               86          19           4
# 9     2746     NOWB         255               89          18           4
# 10    2747     CACW         269               86          19           4
# 11    2748     CACA         272               88          19           4
# ...

# %%
good.shape
# Out:
# (2380, 12)

# %%
plt = sns.regplot(x=good['NumberWorkers'], y=good['IndividUtilization'])
plt.set(xlabel='Number of Workers', ylabel='Total Ridership by Stop')
# Out:
# [Text(0, 0.5, 'Total Ridership by Stop'), Text(0.5, 0, 'Number of Workers')]

# %%
check = pd.read_excel("/Users/HasanMahdi/Desktop/MATH512/PotentialStops_and_RealStops.xlsx", sheet_name = "DupRemoved",usecols = ['CorrespondingStopID','Transfer',])

# %%
check.head(15)
# Out:
#    Transfer CorrespondingStopID
# 0        No                 NaN
# 1        No                 NaN
# 2        No                 NaN
# 3        No                 NaN
# 4        No                 NaN
# 5        No                 NaN
# 6        No                 NaN
# 7        No                 NaN
# 8        No                 NaN
# 9        No                 NaN
# 10       No                 NaN
# 11       No                 250
# 12       No                 NaN
# 13       No                 NaN
# 14       No                 NaN

# %%
check.dropna(inplace=True)
check.head(15)
# Out:
#     Transfer CorrespondingStopID
# 11        No                 250
# 75        No                2280
# 82        No                2282
# 91        No                 251
# 95        No                2283
# 99        No                2284
# 113       No                3644
# 126       No                3223
# 143       No                2288
# 150       No                2289
# 158       No                2290
# 164       No                2291
# 175       No                2293
# 191       No                2169
# 205      Yes                2126

# %%
check.size
# Out:
# 158

# %%
check.rename(columns = {'CorrespondingStopID':'StopId'}, inplace = True)
check.head()
# Out:
#    Transfer StopId
# 11       No    250
# 75       No   2280
# 82       No   2282
# 91       No    251
# 95       No   2283

# %%
checkk = pd.merge(good,check, on= 'StopId',how = 'right')
checkk.head(150)
# Out:
#     StopId StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0     2269     DS03       295.0            167.0       110.0         8.0
# 1     2270     DSWI       518.0            356.0        96.0        23.0
# 2     3559     DSMP       317.0            223.0         9.0        26.0
# 3     2278     DSBV       318.0            224.0         9.0        26.0
# 4     2279     DSVI       323.0            228.0        10.0        27.0
# 5      250     TYBT       220.0            152.0        10.0        12.0
# 6      250     TYBT       220.0            152.0        10.0        12.0
# 7     3644     DHPV       343.0            238.0        12.0        29.0
# 8     3223     DNLB       457.0            316.0        29.0        28.0
# 9     3223     DNLB       457.0            316.0        29.0        28.0
# 10    2288     DN84       732.0            551.0        58.0        42.0
# 11    3945     DSOQ       252.0            138.0        87.0         8.0
# ...

# %%
checkkk = checkk[checkk['Transfer'] == 'No']

# %%
plt = sns.regplot(x=checkkk['NumberWorkers'], y=checkkk['IndividUtilization'])
plt.set(xlabel='Number of Workers', ylabel='Total Ridership by Stop')
# Out:
# [Text(0, 0.5, 'Total Ridership by Stop'), Text(0.5, 0, 'Number of Workers')]

# %%
g = sns.pairplot(good, x_vars = ['Est_TotPop' , 'Est_TotMinority', 'Est_TotPov', 'Est_TotLEP' , 'Stop_PercMinority', 'Stop_PercPoverty' , 'Stop_PercLEP' , 'Est_Pop_Density_SqMile' , 'NumberWorkers'], y_vars = ['IndividUtilization'])
g.fig.set_size_inches(20,10)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
feature_cols = ['Stop_PercMinority', 'Stop_PercPoverty', 'Stop_PercLEP', 'Est_Pop_Density_SqMile' , 'NumberWorkers']
y_cols = ['IndividUtilization']
y=good[y_cols]
x = good[feature_cols]
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state=1)
xTrain = xTrain.fillna(xTrain.mean())
yTrain = yTrain.fillna(yTrain.mean())
xTest = xTest.fillna(xTest.mean())
yTest = yTest.fillna(yTest.mean())
#for col in feature_cols:
#   xTrain[col] = xTrain[col].apply(lambda x: int(x) if x == x else "")
#for col in y_cols:
#   yTrain[col] = yTrain[col].apply(lambda x: int(x) if x == x else "")
#for col in feature_cols:
#   xTest[col] = xTest[col].apply(lambda x: int(x) if x == x else "")


print(xTrain.shape, yTrain.shape)
print(xTest.shape, yTest.shape)
# Out:
# (1904, 5) (1904, 1)
# (476, 5) (476, 1)

# %%
regressor = DecisionTreeRegressor()
regressor.fit(xTrain, yTrain)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = regressor.predict(xTest)
yTest=yTest.IndividUtilization
yTest
# Out:
# 877     0.102319
# 2086    1.071876
# 120     0.248785
# 2266    0.432025
# 107     0.015466
# 1232    0.120169
# 1264    1.241867
# 1684    0.601728
# 2080    0.044627
# 612     0.101240
# 17      0.179139
# 1436    0.265746
# 572     0.650810
# 514     0.026082
# 108     0.685048
# 1087    0.171894
# 1643    0.024337
# 1907    0.865995
# 1027    0.024360
# 1225    0.023590
# 959     0.540624
# 2124    0.087016
# 1006    0.107978
# 2000    0.149913
# 1735    0.493533
# 2041    0.363883
# 1276    0.389988
# 1685    0.730978
# 650     0.049783
# 1032    0.017271
#           ...
# 2028    0.043612
# 2313    0.038832
# 499     0.010591
# 845     4.197559
# 1105    0.359550
# 1017    0.128683
# 1183    0.042718
# 2168    0.218480
# 1355    0.405280
# 181     0.000000
# 406     0.023843
# 1204    0.058333
# 414     0.250643
# 297     0.125046
# 3       0.095721
# 280     0.054097
# 2328    0.176287
# 1370    0.341215
# 1252    0.397619
# 1624    0.229429
# 270     0.389246
# ...

# %%
df=pd.DataFrame({'Actual':yTest, 'Predicted':y_pred})
df
# Out:
#         Actual  Predicted
# 877   0.102319   0.046248
# 2086  1.071876   1.811201
# 120   0.248785   0.121351
# 2266  0.432025   0.157303
# 107   0.015466   0.011151
# 1232  0.120169   0.093861
# 1264  1.241867   0.063153
# 1684  0.601728   0.099997
# 2080  0.044627   0.116774
# 612   0.101240   0.447814
# 17    0.179139   1.122859
# 1436  0.265746   0.953667
# 572   0.650810   0.676486
# 514   0.026082   0.052514
# 108   0.685048   0.120703
# 1087  0.171894   0.365449
# 1643  0.024337   0.178705
# 1907  0.865995   0.202078
# 1027  0.024360   0.082364
# 1225  0.023590   0.347417
# 959   0.540624   0.039810
# 2124  0.087016   0.073831
# 1006  0.107978   0.473288
# 2000  0.149913   0.072003
# 1735  0.493533   0.253530
# 2041  0.363883   0.206761
# 1276  0.389988   0.894354
# 1685  0.730978   0.351328
# 650   0.049783   0.283050
# 1032  0.017271   0.080921
# ...        ...        ...
# 2028  0.043612   0.095022
# 2313  0.038832   0.022113
# 499   0.010591   0.319053
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, y_pred)))
# Out:
# Mean Absolute Error: 0.3524538717896003
# Mean Squared Error: 0.47478878107268835
# Root Mean Squared Error: 0.6890491862506539

# %%
good["IndividUtilization"].mean()
# Out:
# 0.41483176077050293

# %%
0.3524538717896003/0.41483176077050293
# Out:
# 0.8496308747791086

# %%
#So this algorithm is fairly bad at predicting. Need to go back and verify that you used 
#correct data and merged it properly. Garbage in -> Garbage out
#Maybe remove transfer stops
