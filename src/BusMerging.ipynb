# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
orig = "/Users/HasanMahdi/Desktop/MATH512/Potential_Stops.csv"
better = "/Users/HasanMahdi/Desktop/MATH512/DemoByStopsSIMPLIFIED-1.xlsx"

# %%
original = pd.read_csv(orig, usecols = ['StopId','NumberWorkers','AvgNumberVehiclesHH'])
OtherSheet = pd.read_excel(better, sheet_name = 'Stop_DemosForArc', usecols = ['StopId','StopAbbr','Est_TotPop','Est_TotMinority','Est_TotPov','Est_TotLEP','Stop_PercMinority','Stop_PercPoverty', 'Stop_PercLEP','Est_Pop_Density_SqMile'])

# %%
original.head(10)
# Out:
#    StopId  NumberWorkers  AvgNumberVehiclesHH
# 0    3273          851.0                  1.9
# 1    3972          185.0                  1.9
# 2    2720          185.0                  1.9
# 3    2740          851.0                  1.9
# 4    3984          851.0                  1.9
# 5    2998         1320.0                  1.8
# 6    2743         2443.0                  2.2
# 7    2745         1320.0                  1.8
# 8    3560         1320.0                  1.8
# 9    2746         1320.0                  1.8

# %%
OtherSheet.head(10)
# Out:
#    StopId StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0    3273     GSKE         768              297         164          45
# 1    3972     WEAL         712              319         140          42
# 2    2720     WENA         693              300         135          39
# 3    2740     GOGU         367              165          30           9
# 4    3984     RVSC         321              156          17           5
# 5    2998     13SK         250               71          22           3
# 6    2743     CAMA         385              141          24           9
# 7    2745     NOCA         268               86          19           4
# 8    3560     NOVR         264               86          19           4
# 9    2746     NOWB         255               89          18           4
#
#    Stop_PercMinority  Stop_PercPoverty  Stop_PercLEP  Est_Pop_Density_SqMile
# 0              38.67             21.35          5.86                 3911.39
# 1              44.80             19.66          5.90                 3626.19
# 2              43.29             19.48          5.63                 3529.42
# 3              44.96              8.17          2.45                 1869.12
# 4              48.60              5.30          1.56                 1634.84
# 5              28.40              8.80          1.20                 1273.24
# 6              36.62              6.23          2.34                 1960.79
# 7              32.09              7.09          1.49                 1364.91
# 8              32.58              7.20          1.52                 1344.54
# 9              34.90              7.06          1.57                 1298.70

# %%
New = pd.merge(OtherSheet, original, on = 'StopId', how = 'inner')
New.head(100)
# Out:
#     StopId StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0     3273     GSKE         768              297         164          45
# 1     3972     WEAL         712              319         140          42
# 2     2720     WENA         693              300         135          39
# 3     2740     GOGU         367              165          30           9
# 4     3984     RVSC         321              156          17           5
# 5     2998     13SK         250               71          22           3
# 6     2743     CAMA         385              141          24           9
# 7     2745     NOCA         268               86          19           4
# 8     3560     NOVR         264               86          19           4
# 9     2746     NOWB         255               89          18           4
# 10    2747     CACW         269               86          19           4
# 11    2748     CACA         272               88          19           4
# 12    2749     CAST         289               96          20           5
# 13    2750     CAPE         290               97          20           5
# 14    2751     SOCH         341              120          21           6
# 15    2752     SOWE         374              134          22           8
# 16    2753     SODA         395              145          22           8
# 17    2754     VOMA         395              145          22           8
# 18    3402     CAWM         385              146          24           9
# 19    3274     13PO         361              149          27          11
# 20    2774     13FL         329              114          26           6
# 21    2775     13DS         284               87          23           4
# 22    2776     13SH         264               76          23           3
# 23    3152     GORD         337              152          20           6
# 24    2778     GOHA         507              206          77          22
# 25    3973     WEAR         734              327         148          44
# 26    2779     GOCE         746              288         159          43
# 27     551     STRD         333              134          40          14
# 28     552     SCOO         333              135          40          14
# 29     553     SSLA         332              136          41          14
# ..     ...      ...         ...              ...         ...         ...
# 70    3764     CSHM         103               59          26           0
# 71    3006     DL13          56               16           8           1
# 72    3765     13TW          32                7           2           0
# 73    3742     FEL1          35                7           4           0
# 74    3766     13TA          37                7           4           0
# 75    3767     13IH          43               10           4           1
# 76    3768     13CD         125               52          20           2
# 77    3744     MLSD         194               87          32           3
# 78    2759     PELO         239              101          20           6
# 79    3803     PTVA         349              151          29          11
# 80    3982     MMHO         124               27          12           6
# 81    2938     SWBK         270              110          49          29
# 82    2939     SWN2         312              151          56          44
# 83    2943     NWRE         397              242          60          73
# 84    3975     BGCM          33                8           4           1
# 85     453     WMRT         186              118          30          34
# 86    3976     CHBW         627              421         103         129
# 87    3977     CHU5         693              473         116         145
# 88     454     SWPK         384              225          66          68
# 89    2949     SWS2         315              155          56          44
# 90    2951     SWKG         230               63          38          14
# 91    2952     SWWC         231               63          38          14
# 92    2970     525J          28               19           8           3
# 93    3304     18WW          31               21           9           4
# 94    3392     18BP          50               21           7           3
# 95     458     MASS          98               40          22           7
# 96     459     BGSC          85               35          20           6
# 97    2971     MASH          98               40          22           7
# 98    3500     13SM          69               22          13           3
# 99     461     13SV         153               72          39           4
#
#     Stop_PercMinority  Stop_PercPoverty  Stop_PercLEP  Est_Pop_Density_SqMile  \
# 0               38.67             21.35          5.86                 3911.39
# 1               44.80             19.66          5.90                 3626.19
# 2               43.29             19.48          5.63                 3529.42
# 3               44.96              8.17          2.45                 1869.12
# 4               48.60              5.30          1.56                 1634.84
# 5               28.40              8.80          1.20                 1273.24
# 6               36.62              6.23          2.34                 1960.79
# 7               32.09              7.09          1.49                 1364.91
# 8               32.58              7.20          1.52                 1344.54
# 9               34.90              7.06          1.57                 1298.70
# 10              31.97              7.06          1.49                 1370.01
# 11              32.35              6.99          1.47                 1385.28
# 12              33.22              6.92          1.73                 1471.86
# 13              33.45              6.90          1.72                 1476.96
# 14              35.19              6.16          1.76                 1736.70
# 15              35.83              5.88          2.14                 1904.77
# 16              36.71              5.57          2.03                 2011.72
# 17              36.71              5.57          2.03                 2011.72
# 18              37.92              6.23          2.34                 1960.79
# 19              41.27              7.48          3.05                 1838.56
# 20              34.65              7.90          1.82                 1675.58
# 21              30.63              8.10          1.41                 1446.40
# 22              28.79              8.71          1.14                 1344.54
# 23              45.10              5.93          1.78                 1716.33
# 24              40.63             15.19          4.34                 2582.13
# 25              44.55             20.16          5.99                 3738.23
# 26              38.61             21.31          5.76                 3799.35
# 27              40.24             12.01          4.20                 1695.96
# 28              40.54             12.01          4.20                 1695.96
# 29              40.96             12.35          4.22                 1690.86
# ..                ...               ...           ...                     ...
# 70              57.28             25.24          0.00                  524.57
# 71              28.57             14.29          1.79                  285.21
# 72              21.88              6.25          0.00                  162.97
# 73              20.00             11.43          0.00                  178.25
# 74              18.92             10.81          0.00                  188.44
# 75              23.26              9.30          2.33                  219.00
# 76              41.60             16.00          1.60                  636.62
# 77              44.85             16.49          1.55                  988.03
# 78              42.26              8.37          2.51                 1217.22
# 79              43.27              8.31          3.15                 1777.44
# 80              21.77              9.68          4.84                  631.53
# 81              40.74             18.15         10.74                 1375.10
# 82              48.40             17.95         14.10                 1589.00
# 83              60.96             15.11         18.39                 2021.90
# 84              24.24             12.12          3.03                  168.07
# 85              63.44             16.13         18.28                  947.29
# 86              67.15             16.43         20.57                 3193.28
# 87              68.25             16.74         20.92                 3529.42
# 88              58.59             17.19         17.71                 1955.70
# 89              49.21             17.78         13.97                 1604.28
# 90              27.39             16.52          6.09                 1171.38
# 91              27.27             16.45          6.06                 1176.47
# 92              67.86             28.57         10.71                  142.60
# 93              67.74             29.03         12.90                  157.88
# 94              42.00             14.00          6.00                  254.65
# 95              40.82             22.45          7.14                  499.11
# 96              41.18             23.53          7.06                  432.90
# 97              40.82             22.45          7.14                  499.11
# 98              31.88             18.84          4.35                  351.41
# 99              47.06             25.49          2.61                  779.22
#
#     NumberWorkers  AvgNumberVehiclesHH
# 0           851.0                  1.9
# 1           185.0                  1.9
# 2           185.0                  1.9
# 3           851.0                  1.9
# 4           851.0                  1.9
# 5          1320.0                  1.8
# 6          2443.0                  2.2
# 7          1320.0                  1.8
# 8          1320.0                  1.8
# 9          1320.0                  1.8
# 10         1320.0                  1.8
# 11         1320.0                  1.8
# 12         1320.0                  1.8
# 13         1320.0                  1.8
# 14         2443.0                  2.2
# 15         2443.0                  2.2
# 16         2443.0                  2.2
# 17         2443.0                  2.2
# 18         2443.0                  2.2
# 19         2443.0                  2.2
# 20          851.0                  1.9
# 21          851.0                  1.9
# 22          851.0                  1.9
# 23          851.0                  1.9
# 24          851.0                  1.9
# 25          185.0                  1.9
# 26          851.0                  1.9
# 27          851.0                  1.9
# 28          851.0                  1.9
# 29          851.0                  1.9
# ..            ...                  ...
# 70          113.0                  1.4
# 71         1555.0                  1.8
# 72          452.0                  2.2
# 73          452.0                  2.2
# 74          452.0                  2.2
# 75           36.0                  NaN
# 76          458.0                  2.2
# 77          200.0                  1.9
# 78          458.0                  2.2
# 79          419.0                  2.1
# 80          623.0                  1.3
# 81          603.0                  1.8
# 82          603.0                  1.8
# 83          623.0                  1.3
# 84         2662.0                  1.9
# 85         2662.0                  1.9
# 86          623.0                  1.3
# 87          623.0                  1.3
# 88          623.0                  1.3
# 89          623.0                  1.3
# 90          603.0                  1.8
# 91         2458.0                  NaN
# 92          216.0                  2.0
# 93          216.0                  2.0
# 94          216.0                  2.0
# 95          216.0                  2.0
# 96          244.0                  2.6
# 97          216.0                  2.0
# 98          687.0                  2.2
# 99          687.0                  2.2
#
# [100 rows x 12 columns]

# %%
z = pd.read_excel("/Users/HasanMahdi/Desktop/MATH512/Stop_Riders_Ranking_by_Route_Daily_Totals_May_2019.xls", sheet_name = "Arc2019May",usecols = ['StopID','IndividUtilization',])

# %%
z.head()
# Out:
#    StopID  IndividUtilization
# 0       1            2.941645
# 1       1            1.829993
# 2       1            0.568039
# 3       1            0.172715
# 4       2            4.651952

# %%
v = z.StopID.value_counts()
x_new = z[z.StopID.isin(v.index[v.lt(2)])]

# %%
x_new.head(10)
# Out:
#     StopID  IndividUtilization
# 53      24            0.027783
# 54      25            0.065261
# 55      27            0.182908
# 56      28            0.179936
# 57      29            0.541874
# 58      30            0.323668
# 59      31            0.383437
# 60      32            0.024148
# 61      33            0.009532
# 62      34            0.032837

# %%
New.rename(columns={'StopId' : 'StopID'}, inplace=True)

# %%
x_new.head()
# Out:
#     StopID  IndividUtilization
# 53      24            0.027783
# 54      25            0.065261
# 55      27            0.182908
# 56      28            0.179936
# 57      29            0.541874

# %%
good = pd.merge(New,x_new,on = "StopID",how = "inner")
good.head(20)
# Out:
#     StopID StopAbbr  Est_TotPop  Est_TotMinority  Est_TotPov  Est_TotLEP  \
# 0     3273     GSKE         768              297         164          45
# 1     3972     WEAL         712              319         140          42
# 2     2720     WENA         693              300         135          39
# 3     2740     GOGU         367              165          30           9
# 4     3984     RVSC         321              156          17           5
# 5     2998     13SK         250               71          22           3
# 6     2743     CAMA         385              141          24           9
# 7     2745     NOCA         268               86          19           4
# 8     3560     NOVR         264               86          19           4
# 9     2746     NOWB         255               89          18           4
# 10    2747     CACW         269               86          19           4
# 11    2748     CACA         272               88          19           4
# 12    2749     CAST         289               96          20           5
# 13    2750     CAPE         290               97          20           5
# 14    2751     SOCH         341              120          21           6
# 15    2752     SOWE         374              134          22           8
# 16    2753     SODA         395              145          22           8
# 17    2754     VOMA         395              145          22           8
# 18    3274     13PO         361              149          27          11
# 19    2776     13SH         264               76          23           3
#
#     Stop_PercMinority  Stop_PercPoverty  Stop_PercLEP  Est_Pop_Density_SqMile  \
# 0               38.67             21.35          5.86                 3911.39
# 1               44.80             19.66          5.90                 3626.19
# 2               43.29             19.48          5.63                 3529.42
# 3               44.96              8.17          2.45                 1869.12
# 4               48.60              5.30          1.56                 1634.84
# 5               28.40              8.80          1.20                 1273.24
# 6               36.62              6.23          2.34                 1960.79
# 7               32.09              7.09          1.49                 1364.91
# 8               32.58              7.20          1.52                 1344.54
# 9               34.90              7.06          1.57                 1298.70
# 10              31.97              7.06          1.49                 1370.01
# 11              32.35              6.99          1.47                 1385.28
# 12              33.22              6.92          1.73                 1471.86
# 13              33.45              6.90          1.72                 1476.96
# 14              35.19              6.16          1.76                 1736.70
# 15              35.83              5.88          2.14                 1904.77
# 16              36.71              5.57          2.03                 2011.72
# 17              36.71              5.57          2.03                 2011.72
# 18              41.27              7.48          3.05                 1838.56
# 19              28.79              8.71          1.14                 1344.54
#
#     NumberWorkers  AvgNumberVehiclesHH  IndividUtilization
# 0           851.0                  1.9            0.246273
# 1           185.0                  1.9            0.037342
# 2           185.0                  1.9            0.752315
# 3           851.0                  1.9            0.095721
# 4           851.0                  1.9            0.794445
# 5          1320.0                  1.8            0.140216
# 6          2443.0                  2.2            0.046795
# 7          1320.0                  1.8            0.044682
# 8          1320.0                  1.8            0.022864
# 9          1320.0                  1.8            0.097305
# 10         1320.0                  1.8            0.251691
# 11         1320.0                  1.8            0.063834
# 12         1320.0                  1.8            0.036019
# 13         1320.0                  1.8            0.027007
# 14         2443.0                  2.2            0.051133
# 15         2443.0                  2.2            0.001401
# 16         2443.0                  2.2            0.027406
# 17         2443.0                  2.2            0.179139
# 18         2443.0                  2.2            0.045885
# 19          851.0                  1.9            0.312974

# %%
good.shape
# Out:
# (1733, 13)

# %%
plt = sns.regplot(x=good['AvgNumberVehiclesHH'], y=good['IndividUtilization'])
plt.set(xlabel='Number of Vehicles per HH', ylabel='Total Ridership by Stop')
# Out:
# [Text(0, 0.5, 'Total Ridership by Stop'),
#  Text(0.5, 0, 'Number of Vehicles per HH')]

# %%
g = sns.pairplot(good, x_vars = ['Est_TotPop' , 'Est_TotMinority', 'Est_TotPov', 'Est_TotLEP' , 'Stop_PercMinority', 'Stop_PercPoverty' , 'Stop_PercLEP' , 'Est_Pop_Density_SqMile' , 'NumberWorkers','AvgNumberVehiclesHH'], y_vars = ['IndividUtilization'])
g.fig.set_size_inches(20,10)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
feature_cols = ['Stop_PercMinority', 'Stop_PercPoverty', 'Stop_PercLEP', 'Est_Pop_Density_SqMile' , 'NumberWorkers','AvgNumberVehiclesHH']
y_cols = ['IndividUtilization']
y=good[y_cols]
x = good[feature_cols]
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state=1)
xTrain = xTrain.fillna(xTrain.mean())
yTrain = yTrain.fillna(yTrain.mean())
xTest = xTest.fillna(xTest.mean())
yTest = yTest.fillna(yTest.mean())
#for col in feature_cols:
#   xTrain[col] = xTrain[col].apply(lambda x: int(x) if x == x else "")
#for col in y_cols:
#   yTrain[col] = yTrain[col].apply(lambda x: int(x) if x == x else "")
#for col in feature_cols:
#   xTest[col] = xTest[col].apply(lambda x: int(x) if x == x else "")


print(xTrain.shape, yTrain.shape)
print(xTest.shape, yTest.shape)
# Out:
# (1386, 6) (1386, 1)
# (347, 6) (347, 1)

# %%
regressor = DecisionTreeRegressor()
regressor.fit(xTrain, yTrain)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = regressor.predict(xTest)
yTest=yTest.IndividUtilization
yTest
# Out:
# 725     0.706110
# 1357    0.314556
# 1664    0.637152
# 1128    0.785265
# 1583    0.172454
# 1177    0.472945
# 653     0.575356
# 1416    1.273218
# 622     0.536635
# 898     0.272727
# 406     0.287550
# 705     0.402004
# 1382    0.537151
# 1012    0.951678
# 935     0.179077
# 268     0.355043
# 647     0.220125
# 432     0.017772
# 1272    0.030159
# 1073    1.582484
# 1353    0.094667
# 1676    0.226882
# 1457    0.564985
# 194     0.355043
# 366     0.638667
# 810     0.758079
# 1226    0.431458
# 102     0.040260
# 1499    0.090775
# 828     0.039545
#           ...
# 104     0.072189
# 236     0.355043
# 536     0.175474
# 435     0.151511
# 22      0.026092
# 204     0.355043
# 659     1.651068
# 1535    0.173587
# 1260    0.031095
# 1176    0.421237
# 1396    0.246919
# 1426    0.327570
# 1171    0.184746
# 1087    0.002315
# 19      0.312974
# 872     0.140363
# 534     0.505809
# 948     0.096643
# 81      0.203571
# 1131    0.155792
# 51      0.120703
# 259     0.358696
# 718     0.255125
# 1484    0.352195
# 631     0.280714
# 1100    0.277045
# 1438    0.196486
# 1242    0.107289
# 389     0.060288
# 49      0.457687
# Name: IndividUtilization, Length: 347, dtype: float64

# %%
df=pd.DataFrame({'Actual':yTest, 'Predicted':y_pred})
df
# Out:
#         Actual  Predicted
# 725   0.706110   0.135139
# 1357  0.314556   0.436273
# 1664  0.637152   0.702818
# 1128  0.785265   0.440423
# 1583  0.172454   0.304647
# 1177  0.472945   0.550026
# 653   0.575356   0.418582
# 1416  1.273218   0.488537
# 622   0.536635   0.065280
# 898   0.272727   0.008945
# 406   0.287550   0.034603
# 705   0.402004   0.488537
# 1382  0.537151   0.168112
# 1012  0.951678   1.085356
# 935   0.179077   0.304392
# 268   0.355043   0.346771
# 647   0.220125   0.901901
# 432   0.017772   0.054450
# 1272  0.030159   0.020000
# 1073  1.582484   0.371203
# 1353  0.094667   0.230815
# 1676  0.226882   0.291721
# 1457  0.564985   0.406869
# 194   0.355043   0.346771
# 366   0.638667   0.467713
# 810   0.758079   0.584368
# 1226  0.431458   0.696096
# 102   0.040260   0.685048
# 1499  0.090775   0.107669
# 828   0.039545   0.346771
# ...        ...        ...
# 104   0.072189   0.685048
# 236   0.355043   0.346771
# 536   0.175474   0.152637
# 435   0.151511   0.559327
# 22    0.026092   0.522006
# 204   0.355043   0.727273
# 659   1.651068   0.184938
# 1535  0.173587   0.062404
# 1260  0.031095   0.024337
# 1176  0.421237   0.550026
# 1396  0.246919   0.764066
# 1426  0.327570   2.739994
# 1171  0.184746   0.667735
# 1087  0.002315   0.046248
# 19    0.312974   0.174917
# 872   0.140363   0.148773
# 534   0.505809   0.635625
# 948   0.096643   0.415398
# 81    0.203571   0.226627
# 1131  0.155792   0.815639
# 51    0.120703   0.414734
# 259   0.358696   0.205592
# 718   0.255125   0.488537
# 1484  0.352195   0.270694
# 631   0.280714   0.365933
# 1100  0.277045   0.459630
# 1438  0.196486   0.199484
# 1242  0.107289   0.010752
# 389   0.060288   0.633185
# 49    0.457687   0.962136
#
# [347 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, y_pred)))
# Out:
# Mean Absolute Error: 0.2669468423997288
# Mean Squared Error: 0.24143692045328827
# Root Mean Squared Error: 0.4913623107781958

# %%
good["IndividUtilization"].mean()
# Out:
# 0.348431751975233

# %%
0.27993077219916307/0.348431751975233
# Out:
# 0.8034020166424468

# %%
#So this algorithm is fairly bad at predicting. Need to go back and verify that you used 
#correct data and merged it properly. Garbage in -> Garbage out
#Maybe remove transfer stops - Did it. Used stops with only one route. - Added avg num vehciles as well
